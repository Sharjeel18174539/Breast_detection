# %% [markdown]
# Breast Cancer Detection Using KNN Algorithm

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('data.csv')

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.diagnosis.value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
df.diagnosis.value_counts()/len(df)*100
# Out:
# diagnosis
# B    62.741652
# M    37.258348
# Name: count, dtype: float64

# %% [markdown]
# now splitting the data in x and y

# %%
df.dropna(axis=1,inplace=True)

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
x=df.drop(['id', 'diagnosis'], axis=1)

# %%
x
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
y=df.diagnosis.values

# %% [markdown]
# Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test= train_test_split(x,y,test_size=0.25)

# %% [markdown]
# Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train_sc=sc.fit_transform(x_train)
x_test_sc=sc.transform(x_test)

# %%
x_train_sc
# Out:
# array([[-0.23295876,  0.54073377, -0.27583767, ..., -0.88376172,
#         -0.4432405 , -1.01098508],
#        [-0.02184244,  1.86012839, -0.02504704, ..., -0.15722643,
#         -1.05133007, -0.05795368],
#        [ 1.52634384,  2.24317844,  1.69944486, ...,  1.1760987 ,
#         -0.15883685,  0.93290097],
#        ...,
#        [ 0.27372039, -0.68408059,  0.30988507, ...,  0.40268054,
#         -0.51709117, -0.36856284],
#        [-1.14779611, -0.41452685, -1.12664691, ..., -0.75162368,
#         -0.03941875, -0.43446699],
#        [-1.25532468, -0.27974998, -1.26347893, ..., -1.34870847,
#          0.21670167, -0.31354719]])

# %%
from sklearn.neighbors import KNeighborsClassifier

#Initiate the classifier
model_knn=KNeighborsClassifier()

#passing the data to classifier
model_knn.fit(x_train_sc, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_knn=model_knn.predict(x_test_sc)

# %%
y_pred_knn
# Out:
# array(['B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M',
#        'M', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'M', 'B', 'M',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'M', 'B', 'B', 'M', 'M', 'M', 'B', 'M', 'M', 'M', 'B',
#        'B', 'M', 'B', 'B', 'M', 'M', 'M', 'B', 'M', 'M', 'B', 'M', 'B',
#        'M', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'M', 'B',
#        'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'M', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'M', 'B'],
#       dtype=object)

# %%
y_test
# Out:
# array(['B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M',
#        'M', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'M', 'M', 'B', 'M',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'M', 'B', 'B', 'M', 'M', 'M', 'B', 'M', 'M', 'M', 'B',
#        'B', 'M', 'B', 'B', 'M', 'M', 'M', 'B', 'M', 'M', 'B', 'M', 'B',
#        'M', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'M', 'B',
#        'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'M', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'M', 'M'],
#       dtype=object)

# %%
#classification metrics for model behaves

from sklearn.metrics import accuracy_score

print(round(accuracy_score(y_test,y_pred_knn)*100, 2))
# Out:
# 97.9

# %%
new_data=[[	30.57,	17.77,	132.9,	1326,	0.08474,	0.07864,	
           0.0869,	0.07017,	0.1812,	0.05667,	0.5435,	0.7339,	3.398,
           50.08,	0.005225,	0.01308,	0.0186,	0.0134,	0.01389,	
           0.003532,	24.99,	23.41,	158.8,	1567,	0.1238,	0.5866,
           0.2416,	0.386,	0.575,	0.08902]]

# %%
new_data_sc=sc.transform(new_data)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
new_data_sc
# Out:
# array([[ 4.62834618, -0.35777869,  1.6708531 ,  1.89157702, -0.88174718,
#         -0.49940641, -0.03964426,  0.53566182, -0.01248801, -0.87759581,
#          0.49029694, -0.86547751,  0.25750569,  0.19952255, -0.59458045,
#         -0.71179501, -0.4234506 ,  0.25799024, -0.8046096 , -0.10937477,
#          1.77872003, -0.37966249,  1.51303588,  1.18048685, -0.39839074,
#          2.13490839, -0.15885143,  4.04132932,  4.44818802,  0.27500557]])

# %%
y_predict_single=model_knn.predict(new_data_sc)

# %%
y_predict_single
# Out:
# array(['M'], dtype=object)

# %%
new_data_1=[[20.57,	17.77,	132.9,	1326,	0.08474,	0.07864,	0.0869,	0.07017,	0.1812,	0.05667,	0.5435,	0.7339,	3.398,	74.08,	0.005225,	0.01308,	0.0186,	0.0134,	0.01389,	0.003532,	24.99,	23.41,	158.8,	1956,	0.1238,	0.1866,	0.2416,	0.186,	0.275,	0.08902]]

# %%
new_data_1_sc=sc.transform(new_data_1)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
new_data_1_sc
# Out:
# array([[ 1.81346203, -0.35777869,  1.6708531 ,  1.89157702, -0.88174718,
#         -0.49940641, -0.03964426,  0.53566182, -0.01248801, -0.87759581,
#          0.49029694, -0.86547751,  0.25750569,  0.69992142, -0.59458045,
#         -0.71179501, -0.4234506 ,  0.25799024, -0.8046096 , -0.10937477,
#          1.77872003, -0.37966249,  1.51303588,  1.85277911, -0.39839074,
#         -0.44380762, -0.15885143,  1.0551588 , -0.26568463,  0.27500557]])

# %%
ypredic_single=model_knn.predict(new_data_1_sc)

# %%
ypredic_single
# Out:
# array(['M'], dtype=object)
